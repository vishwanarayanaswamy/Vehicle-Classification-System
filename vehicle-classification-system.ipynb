# %% [markdown]
# # Vehicle Classification Project
# Compare Custom CNN, MobileNetV2, and EfficientNetB0. Select the best model, then apply SHAP and Grad-CAM to the best model.

# %%
# File handling
import os
import shutil

# Data processing
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Image processing
from PIL import Image

# Deep learning libraries
import tensorflow as tf
from tensorflow.keras import layers, models

# Transfer learning models
from tensorflow.keras.applications import MobileNetV2, EfficientNetB0

# Evaluation metrics
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    accuracy_score,
    f1_score
)
# Out:
# 2026-06-06 09:28:19.707189: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780738099.732099     146 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780738099.740294     146 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780738099.759449     146 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780738099.759468     146 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780738099.759471     146 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780738099.759474     146 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Define project-wide configuration parameters
SEED = 42
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

# %%
# Create a clean version of the dataset by validating all images,
# converting them to RGB format, and saving them into a new directory.
# This removes corrupted/incompatible files and ensures consistent
# image formatting before training the deep learning models.

SOURCE = "/kaggle/input/datasets/mohamedmaher5/vehicle-classification/Vehicles"
CLEAN = "/kaggle/working/clean_dataset"

os.makedirs(CLEAN, exist_ok=True)

copied = 0
skipped = 0

for cls in os.listdir(SOURCE):

    src_cls = os.path.join(SOURCE, cls)

    if not os.path.isdir(src_cls):
        continue

    dst_cls = os.path.join(CLEAN, cls)

    os.makedirs(dst_cls, exist_ok=True)

    for file in os.listdir(src_cls):

        src_file = os.path.join(src_cls, file)

        try:

            img = Image.open(src_file)

            img = img.convert("RGB")

            save_path = os.path.join(dst_cls, file)

            img.save(save_path, "JPEG")

            copied += 1

        except Exception as e:

            skipped += 1

            print("Skipped:", src_file)

print("Copied:", copied)
print("Skipped:", skipped)
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Copied: 5590
# Skipped: 0

# %%
DATASET_PATH = "/kaggle/working/clean_dataset"

print(os.listdir(DATASET_PATH))
# Out:
# ['Planes', 'Motorcycles', 'Auto Rickshaws', 'Cars', 'Bikes', 'Ships', 'Trains']

# %%
# Load the image dataset, automatically create training and validation splits,
# then further divide the validation set into separate validation and test datasets
# for model training, tuning, and final performance evaluation.
train_ds = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset='training',
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_full = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset='validation',
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_batches = tf.data.experimental.cardinality(val_full)
test_ds = val_full.take(val_batches // 2)
val_ds = val_full.skip(val_batches // 2)

class_names = train_ds.class_names
print(class_names)
# Out:
# Found 5588 files belonging to 7 classes.
# Using 4471 files for training.
# I0000 00:00:1780738171.503428     146 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780738171.509429     146 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Found 5588 files belonging to 7 classes.
# Using 1117 files for validation.
# ['Auto Rickshaws', 'Bikes', 'Cars', 'Motorcycles', 'Planes', 'Ships', 'Trains']

# %%
# Optimize data loading performance and apply preprocessing techniques
# including data augmentation and pixel value normalization to improve
# model generalization and training efficiency.
AUTOTUNE=tf.data.AUTOTUNE
train_ds=train_ds.prefetch(AUTOTUNE)
val_ds=val_ds.prefetch(AUTOTUNE)
test_ds=test_ds.prefetch(AUTOTUNE)

data_augmentation=tf.keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

normalization=layers.Rescaling(1./255)
print(normalization)
# Out:
# <Rescaling name=rescaling, built=False>

# %%
# Sample images
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]])
        plt.axis('off')
plt.tight_layout()
plt.savefig('/kaggle/working/sample_images.pdf')
plt.show()

# %%
# Define training callbacks to prevent overfitting, adjust learning rate,
# and automatically save the best-performing model during training.
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    '/kaggle/working/best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

print("Callbacks created successfully")
# Out:
# Callbacks created successfully

# %%
# Build, compile, and train a custom CNN model for multi-class vehicle image classification.
# The model learns hierarchical image features through convolutional layers and uses
# regularization techniques to improve generalization and reduce overfitting.
# Custom CNN
cnn=models.Sequential([
    data_augmentation,
    normalization,
    layers.Conv2D(32,3,activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128,3,activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(256,3,activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(256,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(class_names),activation='softmax')
])
cnn.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
cnn_history=cnn_history = cnn.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[
        early_stop,
        reduce_lr,
        checkpoint
               
    ]
)

print(
    "Training stopped automatically to avoid overfitting."
)
# Out:
# Epoch 1/50
# I0000 00:00:1780738180.848129     212 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2194 - loss: 2.0178
# Epoch 1: val_accuracy improved from None to 0.36998, saving model to /kaggle/working/best_model.keras
#
# Epoch 1: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 19s 80ms/step - accuracy: 0.2764 - loss: 1.8041 - val_accuracy: 0.3700 - val_loss: 1.5740 - learning_rate: 0.0010
# Epoch 2/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4234 - loss: 1.5213
# Epoch 2: val_accuracy improved from 0.36998 to 0.53229, saving model to /kaggle/working/best_model.keras
#
# Epoch 2: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.4511 - loss: 1.4508 - val_accuracy: 0.5323 - val_loss: 1.2600 - learning_rate: 0.0010
# Epoch 3/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5321 - loss: 1.2720
# Epoch 3: val_accuracy improved from 0.53229 to 0.56021, saving model to /kaggle/working/best_model.keras
#
# Epoch 3: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.5366 - loss: 1.2652 - val_accuracy: 0.5602 - val_loss: 1.3174 - learning_rate: 0.0010
# Epoch 4/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5763 - loss: 1.1789
# Epoch 4: val_accuracy improved from 0.56021 to 0.63002, saving model to /kaggle/working/best_model.keras
#
# Epoch 4: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.5900 - loss: 1.1495 - val_accuracy: 0.6300 - val_loss: 1.0597 - learning_rate: 0.0010
# Epoch 5/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6013 - loss: 1.1016
# Epoch 5: val_accuracy improved from 0.63002 to 0.68063, saving model to /kaggle/working/best_model.keras
#
# Epoch 5: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.6039 - loss: 1.0996 - val_accuracy: 0.6806 - val_loss: 0.8966 - learning_rate: 0.0010
# Epoch 6/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6686 - loss: 0.9550
# Epoch 6: val_accuracy did not improve from 0.68063
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.6513 - loss: 0.9866 - val_accuracy: 0.6789 - val_loss: 0.9662 - learning_rate: 0.0010
# Epoch 7/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6681 - loss: 0.9245
# Epoch 7: val_accuracy improved from 0.68063 to 0.73997, saving model to /kaggle/working/best_model.keras
#
# Epoch 7: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.6786 - loss: 0.9074 - val_accuracy: 0.7400 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 8/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7038 - loss: 0.8547
# Epoch 8: val_accuracy did not improve from 0.73997
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.7023 - loss: 0.8651 - val_accuracy: 0.6963 - val_loss: 0.8856 - learning_rate: 0.0010
# Epoch 9/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7254 - loss: 0.7933
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 9: val_accuracy did not improve from 0.73997
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7238 - loss: 0.8017 - val_accuracy: 0.7190 - val_loss: 0.8883 - learning_rate: 0.0010
# Epoch 10/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7478 - loss: 0.7070
# Epoch 10: val_accuracy improved from 0.73997 to 0.75567, saving model to /kaggle/working/best_model.keras
#
# Epoch 10: finished saving model to /kaggle/working/best_model.keras
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.7627 - loss: 0.6721 - val_accuracy: 0.7557 - val_loss: 0.8262 - learning_rate: 2.0000e-04
# Epoch 11/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7935 - loss: 0.6265
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 11: val_accuracy did not improve from 0.75567
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.7848 - loss: 0.6362 - val_accuracy: 0.7347 - val_loss: 0.8685 - learning_rate: 2.0000e-04
# Epoch 12/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7934 - loss: 0.6001
# Epoch 12: val_accuracy did not improve from 0.75567
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8005 - loss: 0.5881 - val_accuracy: 0.7469 - val_loss: 0.8268 - learning_rate: 4.0000e-05
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Training stopped automatically to avoid overfitting.

# %%
# Implement transfer learning using MobileNetV2 as a pretrained feature extractor.
# The pretrained layers are frozen to retain learned ImageNet features, while a
# custom classification head is trained for vehicle image classification.
# MobileNetV2
base=MobileNetV2(weights='imagenet',include_top=False,input_shape=(224,224,3))
base.trainable=False

mobilenet=models.Sequential([
    data_augmentation,
    normalization,
    base,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(len(class_names),activation='softmax')
])

mobilenet.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
mobile_history=mobile_history = mobilenet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[
        early_stop,
        reduce_lr
    ]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 17s 84ms/step - accuracy: 0.7627 - loss: 0.6854 - val_accuracy: 0.9703 - val_loss: 0.1496 - learning_rate: 0.0010
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8911 - loss: 0.3094 - val_accuracy: 0.9791 - val_loss: 0.0939 - learning_rate: 0.0010
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9146 - loss: 0.2576 - val_accuracy: 0.9791 - val_loss: 0.0928 - learning_rate: 0.0010
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9208 - loss: 0.2239 - val_accuracy: 0.9878 - val_loss: 0.0673 - learning_rate: 0.0010
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9231 - loss: 0.2090 - val_accuracy: 0.9860 - val_loss: 0.0647 - learning_rate: 0.0010
# Epoch 6/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9291 - loss: 0.2060 - val_accuracy: 0.9860 - val_loss: 0.0585 - learning_rate: 0.0010
# Epoch 7/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9360 - loss: 0.1840 - val_accuracy: 0.9808 - val_loss: 0.0764 - learning_rate: 0.0010
# Epoch 8/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9398 - loss: 0.1755 - val_accuracy: 0.9878 - val_loss: 0.0490 - learning_rate: 0.0010
# Epoch 9/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9421 - loss: 0.1734 - val_accuracy: 0.9895 - val_loss: 0.0592 - learning_rate: 0.0010
# Epoch 10/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9366 - loss: 0.1714
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9423 - loss: 0.1642 - val_accuracy: 0.9843 - val_loss: 0.0501 - learning_rate: 0.0010
# Epoch 11/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9463 - loss: 0.1612 - val_accuracy: 0.9843 - val_loss: 0.0592 - learning_rate: 2.0000e-04
# Epoch 12/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9434 - loss: 0.1491 - val_accuracy: 0.9913 - val_loss: 0.0409 - learning_rate: 2.0000e-04
# Epoch 13/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9456 - loss: 0.1581 - val_accuracy: 0.9913 - val_loss: 0.0398 - learning_rate: 2.0000e-04
# Epoch 14/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9456 - loss: 0.1525 - val_accuracy: 0.9825 - val_loss: 0.0640 - learning_rate: 2.0000e-04
# Epoch 15/50
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9586 - loss: 0.1324
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9541 - loss: 0.1397 - val_accuracy: 0.9895 - val_loss: 0.0434 - learning_rate: 2.0000e-04
# Epoch 16/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9477 - loss: 0.1499 - val_accuracy: 0.9860 - val_loss: 0.0560 - learning_rate: 4.0000e-05
# Epoch 17/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9489 - loss: 0.1418
# Epoch 17: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9486 - loss: 0.1417 - val_accuracy: 0.9878 - val_loss: 0.0444 - learning_rate: 4.0000e-05
# Epoch 18/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9465 - loss: 0.1466 - val_accuracy: 0.9860 - val_loss: 0.0475 - learning_rate: 8.0000e-06
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.

# %%
# EfficientNetB0 Transfer Learning Model

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam

# Load pretrained EfficientNetB0
base_eff = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Freeze pretrained layers
base_eff.trainable = False

# Input layer
inputs = tf.keras.Input(shape=(224,224,3))

# Data augmentation
x = data_augmentation(inputs)

# EfficientNet preprocessing
x = preprocess_input(x)

# Feature extraction
x = base_eff(x, training=False)

# Classification head
x = layers.GlobalAveragePooling2D()(x)

x = layers.BatchNormalization()(x)

x = layers.Dropout(0.3)(x)

x = layers.Dense(
    256,
    activation='relu'
)(x)

x = layers.Dropout(0.3)(x)

outputs = layers.Dense(
    len(class_names),
    activation='softmax'
)(x)

# Build model
efficient = Model(inputs, outputs)

# Compile model
efficient.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Model summary
efficient.summary()

# Train model
eff_history = efficient.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[
        early_stop,
        reduce_lr
    ]
)

# Evaluate model
train_loss, train_acc = efficient.evaluate(train_ds)

val_loss, val_acc = efficient.evaluate(val_ds)

print(f"Train Accuracy: {train_acc:.4f}")
print(f"Validation Accuracy: {val_acc:.4f}")

if train_acc - val_acc > 0.10:
    print("Possible overfitting detected.")
else:
    print("No significant overfitting detected.")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,384,426 (16.73 MB)
#  Trainable params: 332,295 (1.27 MB)
#  Non-trainable params: 4,052,131 (15.46 MB)
# Epoch 1/50
# E0000 00:00:1780738500.999469     146 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_3_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 26s 113ms/step - accuracy: 0.6444 - loss: 1.0634 - val_accuracy: 0.9703 - val_loss: 0.3081 - learning_rate: 1.0000e-04
# Epoch 2/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8571 - loss: 0.4366
# Epoch 2: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.8662 - loss: 0.3997 - val_accuracy: 0.9791 - val_loss: 0.0950 - learning_rate: 1.0000e-04
# Epoch 3/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 92ms/step - accuracy: 0.8745 - loss: 0.3564 - val_accuracy: 0.9791 - val_loss: 0.0692 - learning_rate: 2.0000e-05
# Epoch 4/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8922 - loss: 0.3338
# Epoch 4: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - accuracy: 0.8915 - loss: 0.3373 - val_accuracy: 0.9773 - val_loss: 0.0712 - learning_rate: 2.0000e-05
# Epoch 5/50
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 13s 90ms/step - accuracy: 0.8938 - loss: 0.3122 - val_accuracy: 0.9756 - val_loss: 0.0749 - learning_rate: 4.0000e-06
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - accuracy: 0.9711 - loss: 0.3012
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9773 - loss: 0.2917
# Train Accuracy: 0.9711
# Validation Accuracy: 0.9773
# No significant overfitting detected.

# %%
# Evaluate the trained EfficientNetB0 model on the training and validation datasets
# to assess learning performance and identify potential overfitting or underfitting.
train_loss, train_acc = efficient.evaluate(train_ds)
val_loss, val_acc = efficient.evaluate(val_ds)

print("Train Accuracy:", train_acc)
print("Validation Accuracy:", val_acc)
# Out:
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.9711 - loss: 0.3012
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9686 - loss: 0.3006
# Train Accuracy: 0.9711474180221558
# Validation Accuracy: 0.9685863852500916

# %%
def evaluate_model(model,name):
    y_true=[]
    y_pred=[]

    for images,labels in test_ds:
        pred=model.predict(images,verbose=0)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(pred,axis=1))

    acc=accuracy_score(y_true,y_pred)
    f1=f1_score(y_true,y_pred,average='weighted')

    cm=confusion_matrix(y_true,y_pred)

    plt.figure(figsize=(8,6))
    sns.heatmap(cm,annot=True,fmt='d',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title(f'{name} Confusion Matrix')
    plt.savefig(f'/kaggle/working/{name}_confusion_matrix.pdf')
    plt.show()

    report=classification_report(y_true,y_pred,target_names=class_names,output_dict=True)
    pd.DataFrame(report).transpose().to_csv(
        f'/kaggle/working/{name}_classification_report.csv'
    )

    return acc,f1

cnn_acc,cnn_f1=evaluate_model(cnn,'CNN')
mobile_acc,mobile_f1=evaluate_model(mobilenet,'MobileNetV2')
eff_acc,eff_f1=evaluate_model(efficient,'EfficientNetB0')

# %%
comparison=pd.DataFrame({
    'Model':['CNN','MobileNetV2','EfficientNetB0'],
    'Accuracy':[cnn_acc,mobile_acc,eff_acc],
    'F1':[cnn_f1,mobile_f1,eff_f1]
})

comparison=comparison.sort_values('Accuracy',ascending=False)
comparison.to_csv('/kaggle/working/model_comparison.csv',index=False)
comparison
# Out:
#             Model  Accuracy        F1
# 1     MobileNetV2  0.981618  0.981613
# 2  EfficientNetB0  0.965074  0.965086
# 0             CNN  0.700368  0.698461

# %%
best_name=comparison.iloc[0]['Model']

if best_name=='CNN':
    best_model=cnn
elif best_name=='MobileNetV2':
    best_model=mobilenet
else:
    best_model=efficient

print('Best Model:',best_name)
# Out:
# Best Model: MobileNetV2

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

background = next(iter(train_ds))[0][:50].numpy()
sample_images = next(iter(test_ds))[0][:5].numpy()

explainer = shap.GradientExplainer(
    best_model,
    background
)

shap_values = explainer.shap_values(sample_images)

# Create SHAP plot
shap.image_plot(shap_values, sample_images, show=False)

# Save as PDF
plt.savefig(
    "/kaggle/working/SHAP_Explanation.pdf",
    format="pdf",
    bbox_inches="tight"
)

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_173
# Received: inputs=['Tensor(shape=(5, 224, 224, 3))']
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_173
# Received: inputs=['Tensor(shape=(50, 224, 224, 3))']
#   warnings.warn(msg)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..254.36617].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.663000486791134e-09..2.6011548470705748e-09].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.815578798414208e-09..1.6916601452976465e-09].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.317392500117421e-09..2.4519977159798145e-09].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [7.274995..254.99562].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.321030478924513e-09..2.532942744437605e-09].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03125477..239.6824].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-6.071786629036069e-09..5.209585651755333e-09].

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2

last_conv_layer_name = "Conv_1"

# %%
best_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 7)              │         8,967 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,284,887 (8.72 MB)
#  Trainable params: 8,967 (35.03 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 17,936 (70.07 KB)

# %%
# Save models
cnn.save('/kaggle/working/cnn_model.h5')
mobilenet.save('/kaggle/working/mobilenet_model.h5')
efficient.save('/kaggle/working/efficientnetb0_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def plot_history(history, model_name):
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'{model_name} Accuracy')
    plt.legend(['Train','Validation'])

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{model_name} Loss')
    plt.legend(['Train','Validation'])

    plt.tight_layout()
    plt.savefig(f'/kaggle/working/{model_name}_curves.pdf')
    plt.show()

plot_history(cnn_history, "CNN")
plot_history(mobile_history, "MobileNetV2")
plot_history(eff_history, "EfficientNetB0")

# %%
comparison.to_csv(
    "/kaggle/working/model_comparison.csv",
    index=False
)

# %%
y_true = []
y_pred = []

for images, labels in test_ds:

    preds = best_model.predict(images, verbose=0)

    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

misclassified_idx = np.where(
    y_true != y_pred
)[0]

print("Misclassified:", len(misclassified_idx))
# Out:
# Misclassified: 11

# %%
test_images = []
test_labels = []

for images, labels in test_ds:

    test_images.extend(images.numpy())
    test_labels.extend(labels.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

plt.figure(figsize=(15,10))

for i, idx in enumerate(misclassified_idx[:9]):

    plt.subplot(3,3,i+1)

    plt.imshow(
        test_images[idx].astype("uint8")
    )

    plt.title(
        f"True: {class_names[test_labels[idx]]}\n"
        f"Pred: {class_names[y_pred[idx]]}"
    )

    plt.axis("off")

plt.tight_layout()

plt.savefig(
    "/kaggle/working/error_analysis.pdf"
)

plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

# %%
y_true = []
y_prob = []

for images, labels in test_ds:

    preds = best_model.predict(images, verbose=0)

    y_true.extend(labels.numpy())
    y_prob.extend(preds)

y_true = np.array(y_true)
y_prob = np.array(y_prob)

print(y_true.shape)
print(y_prob.shape)
# Out:
# (544,)
# (544, 7)

# %%
n_classes = len(class_names)

y_true_bin = label_binarize(
    y_true,
    classes=np.arange(n_classes)
)

plt.figure(figsize=(10,8))

for i in range(n_classes):

    fpr, tpr, _ = roc_curve(
        y_true_bin[:,i],
        y_prob[:,i]
    )

    roc_auc = auc(
        fpr,
        tpr
    )

    plt.plot(
        fpr,
        tpr,
        label=f'{class_names[i]} AUC={roc_auc:.3f}'
    )

plt.plot(
    [0,1],
    [0,1],
    '--'
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title(
    "Multiclass ROC Curve"
)

plt.legend()

plt.grid(True)

plt.savefig(
    "/kaggle/working/roc_curve.pdf"
)

plt.show()
